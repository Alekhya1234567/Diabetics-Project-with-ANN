# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\ALEKHYA AZMEERA\\OneDrive\\Desktop\\kaggle\\diabetes_prediction_dataset.csv")

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
d={"gender":"Gen","hypertension":"tension","heart_disease":"heart",
   "smoking_history":"smoking","HbA1c_level":"hb_level",
   "blood_glucose_level":"glucose"}
df=df.rename(columns=d)

# %%
df.head()
# Out:
#       Gen   age  tension  heart  smoking    bmi  hb_level  glucose  diabetes
# 0  Female  80.0        0      1    never  25.19       6.6      140         0
# 1  Female  54.0        0      0  No Info  27.32       6.6       80         0
# 2    Male  28.0        0      0    never  27.32       5.7      158         0
# 3  Female  36.0        0      0  current  23.45       5.0      155         0
# 4    Male  76.0        1      1  current  20.14       4.8      155         0

# %%
df.head(20)
# Out:
#        Gen   age  tension  heart  smoking    bmi  hb_level  glucose  diabetes
# 0   Female  80.0        0      1    never  25.19       6.6      140         0
# 1   Female  54.0        0      0  No Info  27.32       6.6       80         0
# 2     Male  28.0        0      0    never  27.32       5.7      158         0
# 3   Female  36.0        0      0  current  23.45       5.0      155         0
# 4     Male  76.0        1      1  current  20.14       4.8      155         0
# 5   Female  20.0        0      0    never  27.32       6.6       85         0
# 6   Female  44.0        0      0    never  19.31       6.5      200         1
# 7   Female  79.0        0      0  No Info  23.86       5.7       85         0
# 8     Male  42.0        0      0    never  33.64       4.8      145         0
# 9   Female  32.0        0      0    never  27.32       5.0      100         0
# 10  Female  53.0        0      0    never  27.32       6.1       85         0
# ...

# %%
df.tail(50)
# Out:
#           Gen   age  tension  heart      smoking    bmi  hb_level  glucose  \
# 99950    Male  20.0        0      0        never  34.69       4.8      145
# 99951    Male  69.0        0      0        never  27.32       6.6      158
# 99952    Male  52.0        0      0       former  27.70       6.2       80
# 99953  Female  59.0        1      0         ever  60.52       3.5      158
# 99954    Male  80.0        0      0      No Info  27.32       6.0       80
# 99955  Female  42.0        0      0        never  27.32       4.0      159
# 99956    Male  26.0        0      0         ever  25.60       6.6       90
# 99957  Female  61.0        0      0      No Info  34.45       6.5      280
# 99958  Female  38.0        0      0  not current  23.58       4.8       85
# 99959  Female  21.0        0      0      No Info  22.90       5.8      158
# 99960  Female  47.0        0      0       former  45.15       4.0      126
# ...

# %%
df.isna().sum()
# Out:
# Gen         0
# age         0
# tension     0
# heart       0
# smoking     0
# bmi         0
# hb_level    0
# glucose     0
# diabetes    0
# dtype: int64

# %%
df["age"]=df["age"].astype(int)

# %%
df
# Out:
#           Gen  age  tension  heart  smoking    bmi  hb_level  glucose  \
# 0      Female   80        0      1    never  25.19       6.6      140
# 1      Female   54        0      0  No Info  27.32       6.6       80
# 2        Male   28        0      0    never  27.32       5.7      158
# 3      Female   36        0      0  current  23.45       5.0      155
# 4        Male   76        1      1  current  20.14       4.8      155
# ...       ...  ...      ...    ...      ...    ...       ...      ...
# 99995  Female   80        0      0  No Info  27.32       6.2       90
# 99996  Female    2        0      0  No Info  17.37       6.5      100
# 99997    Male   66        0      0   former  27.83       5.7      155
# 99998  Female   24        0      0    never  35.42       4.0      100
# 99999  Female   57        0      0  current  22.43       6.6       90
#
#        diabetes
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# ...

# %%
df["bmi"]=df["bmi"].astype(int)

# %%
df
# Out:
#           Gen  age  tension  heart  smoking  bmi  hb_level  glucose  diabetes
# 0      Female   80        0      1    never   25       6.6      140         0
# 1      Female   54        0      0  No Info   27       6.6       80         0
# 2        Male   28        0      0    never   27       5.7      158         0
# 3      Female   36        0      0  current   23       5.0      155         0
# 4        Male   76        1      1  current   20       4.8      155         0
# ...       ...  ...      ...    ...      ...  ...       ...      ...       ...
# 99995  Female   80        0      0  No Info   27       6.2       90         0
# 99996  Female    2        0      0  No Info   17       6.5      100         0
# 99997    Male   66        0      0   former   27       5.7      155         0
# 99998  Female   24        0      0    never   35       4.0      100         0
# 99999  Female   57        0      0  current   22       6.6       90         0
#
# [100000 rows x 9 columns]

# %%
df["hb_level"]=df["hb_level"].astype(int)

# %%
df
# Out:
#           Gen  age  tension  heart  smoking  bmi  hb_level  glucose  diabetes
# 0      Female   80        0      1    never   25         6      140         0
# 1      Female   54        0      0  No Info   27         6       80         0
# 2        Male   28        0      0    never   27         5      158         0
# 3      Female   36        0      0  current   23         5      155         0
# 4        Male   76        1      1  current   20         4      155         0
# ...       ...  ...      ...    ...      ...  ...       ...      ...       ...
# 99995  Female   80        0      0  No Info   27         6       90         0
# 99996  Female    2        0      0  No Info   17         6      100         0
# 99997    Male   66        0      0   former   27         5      155         0
# 99998  Female   24        0      0    never   35         4      100         0
# 99999  Female   57        0      0  current   22         6       90         0
#
# [100000 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

df["Gen"]=label.fit_transform(df["Gen"])
df
# Out:
#        Gen  age  tension  heart  smoking  bmi  hb_level  glucose  diabetes
# 0        0   80        0      1    never   25         6      140         0
# 1        0   54        0      0  No Info   27         6       80         0
# 2        1   28        0      0    never   27         5      158         0
# 3        0   36        0      0  current   23         5      155         0
# 4        1   76        1      1  current   20         4      155         0
# ...    ...  ...      ...    ...      ...  ...       ...      ...       ...
# 99995    0   80        0      0  No Info   27         6       90         0
# 99996    0    2        0      0  No Info   17         6      100         0
# 99997    1   66        0      0   former   27         5      155         0
# 99998    0   24        0      0    never   35         4      100         0
# 99999    0   57        0      0  current   22         6       90         0
#
# [100000 rows x 9 columns]

# %%
df["smoking"]=label.fit_transform(df["smoking"])
df
# Out:
#        Gen  age  tension  heart  smoking  bmi  hb_level  glucose  diabetes
# 0        0   80        0      1        4   25         6      140         0
# 1        0   54        0      0        0   27         6       80         0
# 2        1   28        0      0        4   27         5      158         0
# 3        0   36        0      0        1   23         5      155         0
# 4        1   76        1      1        1   20         4      155         0
# ...    ...  ...      ...    ...      ...  ...       ...      ...       ...
# 99995    0   80        0      0        0   27         6       90         0
# 99996    0    2        0      0        0   17         6      100         0
# 99997    1   66        0      0        3   27         5      155         0
# 99998    0   24        0      0        4   35         4      100         0
# 99999    0   57        0      0        1   22         6       90         0
#
# [100000 rows x 9 columns]

# %% [markdown]
# # Boxplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.boxplot(df)
plt.xticks(rotation=90)
plt.show()

# %%
q1=df["Gen"].quantile(0.25)
q3=df["Gen"].quantile(0.75)

IQR=q3-q1

lower_bound=q1-(1.5)*IQR
upper_bound=q3+(1.5)*IQR

result=df[(df["Gen"]>lower_bound)&(df["Gen"]<upper_bound)]

plt.figure(figsize=(5,3))
sns.boxplot(result['Gen'])
plt.show()

# %%
q1=df["bmi"].quantile(0.28)
q3=df["bmi"].quantile(0.67)

IQR=q3-q1

lower_bound=q1-(1.5)*IQR
upper_bound=q3+(1.5)*IQR

df=df[(df["bmi"]>lower_bound)&(df["bmi"]<upper_bound)]

plt.figure(figsize=(5,3))
sns.boxplot(df["bmi"])
plt.show()

# %%
q1=df["smoking"].quantile(0.25)
q3=df["smoking"].quantile(0.75)

IQR=q3-q1

lower_bound=q1-(1.5)*IQR
upper_bound=q3+(1.5)*IQR

df=df[(df["smoking"]>lower_bound)&(df["smoking"]<upper_bound)]

plt.figure(figsize=(3,2))
sns.boxplot(df["smoking"])
plt.show()

# %%
q1=df["glucose"].quantile(0.25)
q3=df["glucose"].quantile(0.75)

IQR=q3-q1

lower_bound=q1-(1.5)*IQR
upper_bound=q3+(1.5)*IQR

df=df[(df["glucose"]>lower_bound)&(df["glucose"]<upper_bound)]

plt.figure(figsize=(3,2))
sns.boxplot(df["glucose"])
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # countplot graph

# %%
plt.figure(figsize=(5,3))
col=["red","green"]
sns.countplot(x=df['Gen'],data=df,hue="diabetes",palette=col)
# Out:
# <Axes: xlabel='Gen', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
cols=["pink","blue"]
sns.countplot(x=df["smoking"],data=df,hue="diabetes",palette=cols)

plt.show()

# %%
print(df["diabetes"].unique())
# Out:
# [0 1]

# %%
plt.figure(figsize=(5,3))
cols=["pink",'green']
sns.countplot(x=df["heart"],data=df,hue="diabetes",palette=col)
plt.show()

# %% [markdown]
# # frequency graph

# %%
plt.figure(figsize=(5,3))
cols=["pink","red"]
sns.histplot(x=df['age'],data=df,hue="diabetes",palette=cols,kde=True, bins=10)
plt.show()

# %%
plt.figure(figsize=(5,3))
cols=["red","green"]
sns.histplot(x=df['heart'],data=df,hue="diabetes",palette=cols,kde=True, bins=10)
plt.show()

# %% [markdown]
# # correlation

# %%
a=df.corr()
sns.heatmap(a,annot=True,cmap="coolwarm",fmt=".2f")
plt.show()

# %%
from sklearn.model_selection import train_test_split

x=df.drop("diabetes",axis=1).values

y=df.diabetes.values

# %%
x
# Out:
# array([[  0,  80,   0, ...,  25,   6, 140],
#        [  0,  54,   0, ...,  27,   6,  80],
#        [  1,  28,   0, ...,  27,   5, 158],
#        ...,
#        [  0,  80,   0, ...,  27,   6,  90],
#        [  1,  66,   0, ...,  27,   5, 155],
#        [  0,  57,   0, ...,  22,   6,  90]], dtype=int64)

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
#x_train

# %%
#print(y_train)

# %%
import numpy as np
x_train = np.array(x_train, dtype=np.float32)
y_train = np.array(y_train, dtype=np.float32)

# %%
x_train
# Out:
# array([[  0.,  80.,   0., ...,  21.,   6., 155.],
#        [  1.,  26.,   0., ...,  27.,   6., 200.],
#        [  1.,   7.,   0., ...,  27.,   6.,  80.],
#        ...,
#        [  1.,  80.,   0., ...,  31.,   3., 145.],
#        [  0.,  11.,   0., ...,  27.,   6., 158.],
#        [  0.,  33.,   1., ...,  28.,   7., 126.]], dtype=float32)

# %%
y_train
# Out:
# array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
models={"logistic":LogisticRegression(solver="lbfgs",max_iter=5000),
       "decision":DecisionTreeClassifier(),
       "Random":RandomForestClassifier(),
       "svm":SVC(probability=True)}
print(models.items())
# Out:
# dict_items([('logistic', LogisticRegression(max_iter=5000)), ('decision', DecisionTreeClassifier()), ('Random', RandomForestClassifier()), ('svm', SVC(probability=True))])

# %%
import time
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve

# %%
result=[]

for name,model in models.items():
    print(name,model)
    start_time=time.time()
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    run_time=time.time()-start_time
#     print(run_time)
    if hasattr(model,"predict_prob"):
        y_probs=model.predict_prob(y_test)[:,1]
        roc_auc=roc_auc_score(y_test,y_probs)
    else:
         roc_auc="N/A"
    result.append([name,run_time,accuracy,roc_auc])
# Out:
# logistic LogisticRegression(max_iter=5000)
# decision DecisionTreeClassifier()
# Random RandomForestClassifier()
# svm SVC(probability=True)

# %%
cols=["name","run_time","accuracy","roc_auc"]
df_models=pd.DataFrame(columns=cols)

# %%
df_models=pd.DataFrame(result,columns=cols)

# %%
df_models
# Out:
#        name    run_time  accuracy roc_auc
# 0  logistic    0.464405  0.966284     N/A
# 1  decision    0.064772  0.953144     N/A
# 2    Random    5.918327  0.968590     N/A
# 3       svm  377.302907  0.953086     N/A

# %% [markdown]
# # roc_curve

# %%
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score

# %%
accuracy = accuracy_score(y_test, y_pred)
y_probs= model.predict_proba(x_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_probs)
auc_score = roc_auc_score(y_test, y_probs)

plt.figure(figsize=(5,3))
plt.plot(fpr,tpr,label=f'ROC_curve(auc={auc_score:.2f}',color="purple")
plt.plot([0,1],[0,1],linestyle='--' ,label="Random")
plt.title("roc_curve")
#plt.grid()
plt.show()

# %%
import tensorflow

# %%
from tensorflow.keras  import Sequential
from tensorflow.keras.layers import Dense

# %%
model1=Sequential()
model1.add(Dense(units=9,activation='relu'))
model1.add(Dense(units=8,activation='relu'))
model1.add(Dense(units=5,activation='relu'))
model1.add(Dense(units=1,activation='sigmoid'))

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model1.fit(x_train, y_train, validation_split=0.33, batch_size=3, epochs=5)
# Out:
# Epoch 1/5
# d:\Users\ALEKHYA AZMEERA\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 11625/11625 [==============================] - 64s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9453 - val_loss: 0.0000e+00 - val_accuracy: 0.9460
# Epoch 2/5
# 11625/11625 [==============================] - 56s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9453 - val_loss: 0.0000e+00 - val_accuracy: 0.9460
# Epoch 3/5
# 11625/11625 [==============================] - 63s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9453 - val_loss: 0.0000e+00 - val_accuracy: 0.9460
# Epoch 4/5
# 11625/11625 [==============================] - 62s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9453 - val_loss: 0.0000e+00 - val_accuracy: 0.9460
# ...
